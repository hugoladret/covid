# %% [markdown]
# # Reconstructing morphological structure of layers from Allen data
# See [this file](https://www.dropbox.com/sh/w5u31m3hq6u2x5m/AAD34a7F63f7nRYUq2vLR3sha/build_model/column_structure.xlsx?dl=0) or excel file in morphologies folder for model parameters

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

import brian2 as b2

import copy

from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
from allensdk.core.cell_types_cache import ReporterStatus as RS

import neurom as nm
from neurom import viewer

np.random.seed(42)
# Out:
# INFO       Cache size for target "cython": 2178 MB.
# You can call "clear_cache('cython')" to delete all files from the cache or manually delete files in the "/home/hugo/.cython/brian_extensions" directory. [brian2]

# %% [markdown]
# # Morphological parameters

# %%
# Relative percentage of E/I cells
frac_exc = .85
frac_inh = 1.-frac_exc

# Layer median thickness (um)
layer_thickness = {1 : 100,
                  2 : 210,
                  4 : 120,
                  5 : 220,
                  6 : 200}

# Cell counts per layer (scaled)
density_scale = .001
layer_density = {1 : 0 * density_scale,
                2 : 65949 * density_scale,
                4 : 53837 * density_scale,
                5 : 39480 * density_scale,
                6 : 67296 * density_scale}

# Layer morphotypes {layer : [(type, fraction)]}
layer_morphology = {1 : [('NO CELLS', .0)],
                    2 : [('Cux2', 1.)],
                    4 : [('Scnn1a', .3),
                         ('Rorb', .25),
                         ('Nr5a1', .12)],
                    5 : [('Rbp4', 1.)],
                    6 : [('Ntsr1', .8)]}

# %% [markdown]
# # Querying Allen DBs for morphological files

# %%
# Initiates the CellTypes constructor
morpho_path = '../morphologies/'
ctc = CellTypesCache(morpho_path) 

# Get all reconstructed mice neurons
cells = ctc.get_cells(require_reconstruction = True, 
                      species=[CellTypesApi.MOUSE])
print('Found %s cells in Allen DB' % len(cells))
# Out:
# Found 485 cells in Allen DB

# %%
# Filter cells to keep only V1 neurons with a specific names
layer_dict = {1 : [], 2 : [], 4 : [], 5 : [], 6 : []}
for cell in tqdm(cells, total = len(cells), desc = 'Fetching cells...') :
    if cell['structure_area_abbrev'] == 'VISp':
        layer = int(cell['structure_layer_name'][0]) #[0] eliminates the 2/3, 6a, 4b...
        morphotypes = layer_morphology[layer] # get the layer morphotypes names
        for types in morphotypes :
            if types[0] in cell['name'] :
                morpho = ctc.get_reconstruction(specimen_id = cell['id'],
                                            file_name = morpho_path + cell['name']  + '.swc')
                layer_dict[layer].append([cell['name'], cell['id'], morpho, morpho_path + cell['name']  + '.swc' ])
    else :
        pass
# Out:
# Fetching cells...: 100%|██████████| 485/485 [00:03<00:00, 152.10it/s]

# %% [markdown]
# # Creating an array of correct proportion of morphotypes for each layer

# %%
layer_array = {1 : [], 2 : [], 4 : [], 5 : [], 6 : []}
for layer, items in tqdm(layer_dict.items(), total = len(layer_dict), desc = 'Loading and shuffling morphologies') :
    _ = []
    for morph_tuples in layer_morphology[layer] :
        name_morpho = morph_tuples[0]
        fract_morpho = morph_tuples[1]
        
        density = layer_density[layer]
        n_cells = fract_morpho * density
        
        morpholist = [nm.load_neuron(x[-1]) for x in layer_dict[layer] if name_morpho in x[0]]
        morph_array = np.resize(morpholist, int(n_cells))
        np.random.shuffle(morph_array)
        
        _.append(morph_array)
    layer_array[layer].append(np.concatenate(_))
# Out:
# Loading and shuffling morphologies: 100%|██████████| 5/5 [00:01<00:00,  2.60it/s]

# %% [markdown]
# # Distributing center of mass in ONE layer volume
# ### ATM with a grid, but later with optimal packing or sphere packing
# ### Note : SVC files coordinates are in micrometers

# %%
example_layer = layer_array[2][0]

X = 1000 #um, size of the volume
Y = X
safety_margin = X / np.sqrt(len(example_layer))  #um, safety margins between two neurons

# Making coordinates
xs = np.arange(0, X, safety_margin)
ys = np.arange(0, Y, safety_margin)
zs = np.linspace(0., .75, 5, endpoint = False)

if zs.size == 0 : zs = np.array([0], dtype = np.int16)
    
xx,yy = np.meshgrid(xs, ys)
mesh = np.dstack([xx,yy]).reshape(-1, 2)

# %%
tot_scatter = 30 #number of neurons to display
scatter_frequency = 5 # proportion of the points in a neuron to scatter

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection = '3d')

scatter_idx = np.linspace(0, len(example_layer), tot_scatter,
                          dtype = np.int16,
                          endpoint = False)
colors = plt.cm.plasma(np.linspace(0,1,tot_scatter))
for i0, coordinate in tqdm(enumerate(mesh), total = len(mesh), desc = 'Rendering neurons') :
    x = coordinate[0]
    y = coordinate[1]
    z = np.random.choice(zs) * layer_thickness[2]
    
    if i0 in scatter_idx :
        points = example_layer[i0].points[::scatter_frequency]
        for pts in points :
            ax.scatter(x + pts[0], y + pts[1], z + pts[2],
                      color = colors[np.where(scatter_idx == i0)[0][0]])
    
    ax.scatter(x,y,z)
    
ax.view_init(elev = 5, azim = 45)
fig.savefig('../figs/onelayer.png', format = 'png', dpi = 200)
plt.show()
# Out:
# Rendering neurons: 100%|██████████| 81/81 [00:35<00:00,  2.30it/s]

# %% [markdown]
# # For all layers

# %%
X = 1000
Y = X

fract_scatter = .25  # fraction of neuron to scatter per layer
scatter_frequency = 5  # proportion of the points in a neuron to scatter

curr_z = 0  # iterate the z NEGATIVELY !! for layer depth
for layer, items in layer_array.items():
    # Aliasing
    layer_content = items[0]

    # Coordinates
    safety_margin = X / np.sqrt(len(layer_content))
    xs = np.arange(0, X, safety_margin)
    ys = np.arange(0, Y, safety_margin)
    xx, yy = np.meshgrid(xs, ys)
    mesh = np.dstack([xx, yy]).reshape(-1, 2)
    
    zs = np.linspace(0., .75, 5, endpoint = False)
    if zs.size == 0:
        zs = np.array([0], dtype=np.int16)
       
    
    # Plotting arrays
    scatter_idx = np.linspace(0, len(layer_content), int(len(layer_content) * fract_scatter),
                              dtype=np.int16,
                              endpoint=False)
    colors = plt.cm.plasma(np.linspace(0. ,1. ,len(scatter_idx)))
    
    # Plotting
    for i0, coordinate in tqdm(enumerate(mesh), total = len(mesh),
                               desc = 'Rendering layer %s neurons...' % layer) :
        x = coordinate[0]
        y = coordinate[1]
        z = np.random.choice(zs) * layer_thickness[layer] + curr_z
        if i0 in scatter_idx :
            points = layer_content[i0].points[::scatter_frequency]
            for pts in points :
                ax.scatter(x + pts[0], y + pts[1], z + pts[2],
                          color = colors[np.where(scatter_idx == i0)[0][0]])
        else :
            ax.scatter(x,y,z)
    
    # Updating
    curr_z -= layer_thickness[layer]
    
ax.view_init(elev = 5, azim = 45)
fig.savefig('../figs/all_layers.png', format = 'png', dpi = 300)
plt.show()
# Out:
# WARNING    /home/hugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in double_scalars
#   del sys.path[0]
#  [py.warnings]
# Rendering layer 1 neurons...: 100%|██████████| 1/1 [00:00<00:00, 584.82it/s]
# Rendering layer 2 neurons...: 100%|██████████| 81/81 [00:18<00:00,  4.34it/s]
# Rendering layer 4 neurons...: 100%|██████████| 36/36 [00:04<00:00,  8.50it/s]
# Rendering layer 5 neurons...: 100%|██████████| 49/49 [00:07<00:00,  6.37it/s]
# Rendering layer 6 neurons...: 100%|██████████| 64/64 [00:08<00:00,  7.34it/s]
